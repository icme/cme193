# %% [markdown]
# # Intro to Pandas (and a bit of Seaborn)
#
# In this notebook we will go over the basics of Pandas, a very popular Python module to deal with data.
#
# ### Other resources
#
# - [Pandas Cookbook](https://github.com/jvns/pandas-cookbook) Great in-depth tutorial using real data

# %%
# %matplotlib inline

import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("dark")
sns.set_context("talk")

# %% [markdown]
# ## Iris Data
#
# For this notebook, we use the standard Iris data set! Also, its possible to load data from online sources!

# %%
iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', 
                 header=None,
                 names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species'])

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
sns.pairplot(iris, hue='species')

# %%
sns.corrplot(iris.drop('species', 1))

# %%
# -- can index using dot notation!
iris.sepal_length
# Out:
# 0     5.1
# 1     4.9
# 2     4.7
# 3     4.6
# 4     5.0
# 5     5.4
# 6     4.6
# 7     5.0
# 8     4.4
# 9     4.9
# 10    5.4
# 11    4.8
# 12    4.8
# 13    4.3
# 14    5.8
# ...
# 135    7.7
# 136    6.3
# 137    6.4
# 138    6.0
# 139    6.9
# 140    6.7
# 141    6.9
# 142    5.8
# 143    6.8
# 144    6.7
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
print 'The mean sepal length is {}'.format(iris.sepal_length.mean())
# Out:
# The mean sepal length is 5.84333333333

# %%
iris.sepal_length.ix[0]
# Out:
# 5.0999999999999996
